# %%
# !python main.py --train_benchmark_selected gsm8k --test_benchmark_selected gsm8k

# %%
# !python main.py --train_benchmark_selected math --test_benchmark_selected

# %%
# !python main.py --train_benchmark_selected humaneval --test_benchmark_selected humaneval

# %%
# !python main.py --train_benchmark_selected drop --test_benchmark_selected drop

# %%
# !python main.py --train_benchmark_selected gpqa --test_benchmark_selected gpqa

# %%
# !python main.py --train_benchmark_selected mmlu --test_benchmark_selected mmlu

# %%
# !python main.py --train_benchmark_selected mbpp --test_benchmark_selected mbpp
